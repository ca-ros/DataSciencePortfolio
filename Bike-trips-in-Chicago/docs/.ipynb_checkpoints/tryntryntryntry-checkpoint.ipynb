# %%
# Importing required packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.figure
import seaborn as sns

plt.style.use('seaborn')

# %%
data = pd.read_csv(
        "202102.csv",
        dtype = {
            'start_station_id': pd.Int64Dtype(),
            'end_station_id' : pd.Int64Dtype()
            })

# Use data.info() instead

# %%
plt?
# Out:
# Type:        module
# String form: <module 'matplotlib.pyplot' from 'c:\\Users\\Chris\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\matplotlib\\pyplot.py'>
# File:        c:\users\chris\appdata\local\programs\python\python310\lib\site-packages\matplotlib\pyplot.py
# Docstring:
# `matplotlib.pyplot` is a state-based interface to matplotlib. It provides
# an implicit,  MATLAB-like, way of plotting.  It also opens figures on your
# screen, and acts as the figure GUI manager.
#
# pyplot is mainly intended for interactive plots and simple cases of
# programmatic plot generation::
#
#     import numpy as np
#     import matplotlib.pyplot as plt
#
#     x = np.arange(0, 5, 0.1)
#     y = np.sin(x)
#     plt.plot(x, y)
#
# The explicit (object-oriented) API is recommended for complex plots, though
# pyplot is still usually used to create the figure and often the axes in the
# figure. See `.pyplot.figure`, `.pyplot.subplots`, and
# `.pyplot.subplot_mosaic` to create figures, and
# :doc:`Axes API <../axes_api>` for the plotting methods on an axes::
#
#     import numpy as np
#     import matplotlib.pyplot as plt
#
#     x = np.arange(0, 5, 0.1)
#     y = np.sin(x)
#     fig, ax = plt.subplots()
#     ax.plot(x, y)

# %%
# Remove columns without data, since these data are only available on 2013-2019
data.drop(['bike_id', 'gender', 'birth_year'], axis = 1, inplace = True)
data.head()
# Out:
#             ride_id  rideable_type           start_time             end_time  \
# 0  19A112436EC92A7E   classic_bike  2021-02-01 00:55:44  2021-02-01 10:44:58
# 1  05A7BDE8A0D909FC  electric_bike  2021-02-01 01:07:04  2021-02-01 01:47:45
# 2  CAC54BCCD36F6B15  electric_bike  2021-02-01 01:15:19  2021-02-01 01:22:48
# 3  B12AD1843BE99A2C   classic_bike  2021-02-01 01:56:22  2021-02-01 01:59:23
# 4  A62978A16B1FFE79   classic_bike  2021-02-01 01:59:41  2021-02-01 02:21:23
#
#    trip_duration  start_station_id            start_station_name  \
# 0          35354               322         Kimbark Ave & 53rd St
# 1           2441               498  California Ave & Fletcher St
# 2            449               192           Canal St & Adams St
# 3            181               192           Canal St & Adams St
# 4           1302               638     Clinton St & Jackson Blvd
#
#    end_station_id              end_station_name user_type
# 0            <NA>                           NaN    member
# 1             455  Maplewood Ave & Peterson Ave    casual
# 2            <NA>                           NaN    member
# 3             107  Desplaines St & Jackson Blvd    member
# 4             172            Rush St & Cedar St    member

# %%
# Converting objects to datetime
data[['start_time', 'end_time']] = data[['start_time', 'end_time']].apply(pd.to_datetime, format = '%Y-%m-%d %H:%M:%S')
data.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# start_time            datetime64[ns]
# end_time              datetime64[ns]
# trip_duration                  int64
# start_station_id               Int64
# start_station_name            object
# end_station_id                 Int64
# end_station_name              object
# user_type                     object
# dtype: object

# %%
# Removing rows where station names are nulls
data.dropna(subset = ['start_station_name', 'end_station_name'], inplace = True)
print('The number of nulls on station name columns\n')
print(data[['start_station_name', 'end_station_name']].isnull().sum())
# Out:
# The number of nulls on station name columns
#
# start_station_name    0
# end_station_name      0
# dtype: int64

# %%
data['trip_duration'].plot(kind = 'density', figsize = (14,6))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
ax = data['ride_id'].plot(kind = 'hist', figsize = (14,6))
ax.set_ylabel('Date')
ax.set_xlabel('Count')

# %%
data.set_index('start_time',inplace = True)

# %%
data.head()
# Out:
#             ride_id  rideable_type          start_time            end_time  \
# 1  05A7BDE8A0D909FC  electric_bike 2021-02-01 01:07:04 2021-02-01 01:47:45
# 3  B12AD1843BE99A2C   classic_bike 2021-02-01 01:56:22 2021-02-01 01:59:23
# 4  A62978A16B1FFE79   classic_bike 2021-02-01 01:59:41 2021-02-01 02:21:23
# 5  191F68D78FC5E76B  electric_bike 2021-02-01 03:03:30 2021-02-01 03:10:34
# 7  6D4D1A96830EBD3C   classic_bike 2021-02-01 04:40:26 2021-02-01 04:59:51
#
#    trip_duration  start_station_id            start_station_name  \
# 1           2441               498  California Ave & Fletcher St
# 3            181               192           Canal St & Adams St
# 4           1302               638     Clinton St & Jackson Blvd
# 5            424               349   Halsted St & Wrightwood Ave
# 7           1165               622    California Ave & Cortez St
#
#    end_station_id              end_station_name user_type
# 1             455  Maplewood Ave & Peterson Ave    casual
# 3             107  Desplaines St & Jackson Blvd    member
# 4             172            Rush St & Cedar St    member
# 5             304       Broadway & Waveland Ave    casual
# 7             622    California Ave & Cortez St    casual

# %%
date = data['start_time']
casual = data[data['user_type'] == 'casual']
member = data[data['user_type'] == 'member']

# plt.bar(date, casual, color = '#f9b665', label = 'Casual')
# plt.bar(date, member, color = '#ff00ff', label = 'Member')

# plt.title('Trip Trend')
# plt.xlabel('Date')
# plt.ylabel('Count')
# plt.legend()
# plt.tight_layout()
# plt.show()

# %%
a = data.groupby(
    pd.Grouper(
        key = 'start_time', 
        axis = 0,
        freq = 'D',
        sort = True
    )).size()

print(a)
# Out:
# start_time
# 2021-02-01    1496
# 2021-02-02    1941
# 2021-02-03    2265
# 2021-02-04    1416
# 2021-02-05    1028
# 2021-02-06     643
# 2021-02-07     511
# 2021-02-08     822
# 2021-02-09    1150
# 2021-02-10    1089
# 2021-02-11    1139
# 2021-02-12    1510
# 2021-02-13     571
# 2021-02-14     444
# 2021-02-15     304
# 2021-02-16     217
# 2021-02-17     482
# 2021-02-18     638
# 2021-02-19     770
# 2021-02-20     890
# 2021-02-21     722
# 2021-02-22    1251
# 2021-02-23    2447
# 2021-02-24    2786
# 2021-02-25    2792
# 2021-02-26    3467
# 2021-02-27    6520
# 2021-02-28    2990
# Freq: D, dtype: int64

# %%
plt.plot(a)
plt.xlabel('Date')
plt.ylabel('Trip count')
plt.figure(figsize = (16,8), dpi = 80)

# %%
plt.plot?

# %%
a2 = casual.groupby(
    pd.Grouper(
        key = 'start_time', 
        axis = 0,
        freq = 'D',
        sort = True
    )).size()

a3 = member.groupby(
    pd.Grouper(
        key = 'start_time', 
        axis = 0,
        freq = 'D',
        sort = True
    )).size()

# %%
plt.plot(a2, color = '#f9b665', label = 'Casual')
plt.plot(a3, color = '#59504e', label = 'Member')

plt.legend()
plt.xlabel('Date')
plt.ylabel('Trip count')
# Out:
# Text(0, 0.5, 'Trip count')

# %%
ax = a

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.cbook as cbook

# Load a numpy record array from yahoo csv data with fields date, open, high,
# low, close, volume, adj_close from the mpl-data/sample_data directory. The
# record array stores the date as an np.datetime64 with a day unit ('D') in
# the date column.
data = cbook.get_sample_data('goog.npz', np_load=True)['price_data']

fig, axs = plt.subplots(3, 1, figsize=(6.4, 7), constrained_layout=True)
# common to all three:
for ax in axs:
    ax.plot('date', 'adj_close', data=data)
    # Major ticks every half year, minor ticks every month,
    ax.xaxis.set_major_locator(mdates.MonthLocator(bymonth=(1, 7)))
    ax.xaxis.set_minor_locator(mdates.MonthLocator())
    ax.grid(True)
    ax.set_ylabel(r'Price [\$]')

# different formats:
ax = axs[0]
ax.set_title('DefaultFormatter', loc='left', y=0.85, x=0.02, fontsize='medium')

ax = axs[1]
ax.set_title('ConciseFormatter', loc='left', y=0.85, x=0.02, fontsize='medium')
ax.xaxis.set_major_formatter(
    mdates.ConciseDateFormatter(ax.xaxis.get_major_locator()))

ax = axs[2]
ax.set_title('Manual DateFormatter', loc='left', y=0.85, x=0.02,
             fontsize='medium')
# Text in the x axis will be displayed in 'YYYY-mm' format.
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%b'))
# Rotates and right-aligns the x labels so they don't crowd each other.
for label in ax.get_xticklabels(which='major'):
    label.set(rotation=30, horizontalalignment='right')

plt.show()

# %%
data[data['user_type'] == 'member'].value_counts()

# %%
data['user_type'].value_counts().plot(kind = 'bar', figsize = (18,6))
# Out:
# <AxesSubplot:>

# %%
data['user_type'].value_counts().plot(kind = 'pie', figsize = (6, 6))
# Out:
# <AxesSubplot:ylabel='user_type'>

# %%
users = data['user_type'].value_counts()

ax = data[['duration', 'rideable_type']].boxplot(by = 'rideable_type', figsize = (10,6))
ax.set_ylabel('Trip Duration')

# %%
t1 = data['start_time']
t2 = data['end_time']

data['duration'] = (t2-t1)
data['duration'] = data['duration'].astype('timedelta64[s]')
data['duration'] = data['duration'].astype('int32')

# %%
data['duration'].head()

# %%
data.info()

# %%
print(pd.Series({"Memory usage": "{:.4f} MB".format(data.memory_usage().sum()/(1024*1024)),
                 "Dataset shape": "{}".format(data.shape)}).to_string())
